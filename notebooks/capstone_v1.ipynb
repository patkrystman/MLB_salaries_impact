# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as py
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
# pip install pybaseball

# %%
import pybaseball as pybal

# %%
# mariners_2018['Wins'] = py.where(mariners_2018['W/L']=='W', 1, (py.where(mariners_2018['W/L']=='W-wo', 1, 0))).cumsum()
# mariners_2018['Losses'] = py.where(mariners_2018['W/L']=='L', 1, (py.where(mariners_2018['W/L']=='L-wo', 1, 0))).cumsum()
# mariners_2018['Win_Percentage'] = mariners_2018['Wins'] / (mariners_2018['Wins'] + mariners_2018['Losses'])

# %%
pyball.schedule_and_record(2018, 'SEA').sort_values('GB', ascending=False)
# Out:
# http://www.baseball-reference.com/teams/SEA/2018-schedule-scores.shtml
#                 Date   Tm Home_Away  Opp   W/L    R   RA   Inn    W-L  Rank  \
# 60    Tuesday, Jun 5  SEA         @  HOU     W  7.0  1.0   9.0  38-22   1.0
# 63     Friday, Jun 8  SEA         @  TBR     W  4.0  3.0   9.0  40-23   1.0
# 62   Thursday, Jun 7  SEA         @  TBR     W  5.0  4.0   9.0  39-23   1.0
# 61  Wednesday, Jun 6  SEA         @  HOU     L  5.0  7.0   9.0  38-23   1.0
# 59     Sunday, Jun 3  SEA      Home  TBR     W  2.0  1.0   9.0  37-22   1.0
# ..               ...  ...       ...  ...   ...  ...  ...   ...    ...   ...
# 85     Sunday, Jul 1  SEA      Home  KCR     W  1.0  0.0   9.0  54-31   2.0
# 86    Tuesday, Jul 3  SEA      Home  LAA     W  4.0  1.0   9.0  55-31   2.0
# 32   Saturday, May 5  SEA      Home  LAA  W-wo  9.0  8.0  11.0  19-13   3.0
# 30   Thursday, May 3  SEA      Home  OAK     W  4.0  1.0   9.0  18-12   3.0
# ...

# %%
years = pyball.schedule_and_record()

# %%
sched = pyball.schedule_and_record(years, 'SEA')
sched.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 sched = pyball.schedule_and_record(years, 'SEA')
#       2 sched.head()
#
# NameError: name 'years' is not defined

# %%
pybal.schedule_and_record
# Out:
# <function pybaseball.team_results.schedule_and_record(season: int, team: str) -> pandas.core.frame.DataFrame>

# %%
filtered_df = df[(df['Year'] >= 2002) & (df['Year'] <= 2005)]
print(filtered_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 filtered_df = df[(df['Year'] >= 2002) & (df['Year'] <= 2005)]
#       2 print(filtered_df)
#
# TypeError: 'function' object is not subscriptable
